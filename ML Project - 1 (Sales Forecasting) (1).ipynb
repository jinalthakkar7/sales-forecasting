# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('train.csv')

# %%
data.head(3)
# Out:
#    Row ID        Order ID  Order Date   Ship Date     Ship Mode Customer ID  \
# 0       1  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 1       2  CA-2017-152156  08/11/2017  11/11/2017  Second Class    CG-12520
# 2       3  CA-2017-138688  12/06/2017  16/06/2017  Second Class    DV-13045
#
#      Customer Name    Segment        Country         City       State  \
# 0      Claire Gute   Consumer  United States    Henderson    Kentucky
# 1      Claire Gute   Consumer  United States    Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States  Los Angeles  California
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# 0      42420.0  South  FUR-BO-10001798        Furniture    Bookcases
# 1      42420.0  South  FUR-CH-10000454        Furniture       Chairs
# 2      90036.0   West  OFF-LA-10000240  Office Supplies       Labels
#
#                                         Product Name   Sales
# ...

# %%
data.tail(3)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country    City State  \
# 9797    CS-12490  Cindy Schnelling  Corporate  United States  Toledo  Ohio
# 9798    CS-12490  Cindy Schnelling  Corporate  United States  Toledo  Ohio
# 9799    CS-12490  Cindy Schnelling  Corporate  United States  Toledo  Ohio
#
#       Postal Code Region       Product ID    Category Sub-Category  \
# 9797      43615.0   East  TEC-PH-10004977  Technology       Phones
# 9798      43615.0   East  TEC-PH-10000912  Technology       Phones
# 9799      43615.0   East  TEC-AC-10000487  Technology  Accessories
#
#                                   Product Name    Sales
# 9797                               GE 30524EE4  235.188
# ...

# %%
data.shape
# Out:
# (9800, 18)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9800 entries, 0 to 9799
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9800 non-null   int64
#  1   Order ID       9800 non-null   object
#  2   Order Date     9800 non-null   object
#  3   Ship Date      9800 non-null   object
#  4   Ship Mode      9800 non-null   object
#  5   Customer ID    9800 non-null   object
#  6   Customer Name  9800 non-null   object
#  7   Segment        9800 non-null   object
#  8   Country        9800 non-null   object
#  9   City           9800 non-null   object
#  10  State          9800 non-null   object
#  11  Postal Code    9789 non-null   float64
#  12  Region         9800 non-null   object
#  13  Product ID     9800 non-null   object
#  14  Category       9800 non-null   object
#  15  Sub-Category   9800 non-null   object
#  16  Product Name   9800 non-null   object
# ...

# %%
data.describe()
# Out:
#             Row ID   Postal Code         Sales
# count  9800.000000   9789.000000   9800.000000
# mean   4900.500000  55273.322403    230.769059
# std    2829.160653  32041.223413    626.651875
# min       1.000000   1040.000000      0.444000
# 25%    2450.750000  23223.000000     17.248000
# 50%    4900.500000  58103.000000     54.490000
# 75%    7350.250000  90008.000000    210.605000
# max    9800.000000  99301.000000  22638.480000

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales'],
#       dtype='object')

# %%
data.isna()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9795   False     False       False      False      False        False
# 9796   False     False       False      False      False        False
# 9797   False     False       False      False      False        False
# 9798   False     False       False      False      False        False
# 9799   False     False       False      False      False        False
#
#       Customer Name  Segment  Country   City  State  Postal Code  Region  \
# ...

# %%
data.isna().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
data.dropna(axis=0, inplace=True)

# %%
data.isna().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %%
data.dtypes
# Out:
# Row ID             int64
# Order ID          object
# Order Date        object
# Ship Date         object
# Ship Mode         object
# Customer ID       object
# Customer Name     object
# Segment           object
# Country           object
# City              object
# State             object
# Postal Code      float64
# Region            object
# Product ID        object
# Category          object
# Sub-Category      object
# Product Name      object
# Sales            float64
# dtype: object

# %%
data['Postal Code']=data['Postal Code'].astype(int)

# %%
data['Sales']=data['Sales'].astype(int)

# %%
data.dtypes
# Out:
# Row ID            int64
# Order ID         object
# Order Date       object
# Ship Date        object
# Ship Mode        object
# Customer ID      object
# Customer Name    object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int32
# Region           object
# Product ID       object
# Category         object
# Sub-Category     object
# Product Name     object
# Sales             int32
# dtype: object

# %%
data['Order Date'] = pd.to_datetime(data['Order Date'], format='%d/%m/%Y')
data['Ord_Day'] = data['Order Date'].dt.day
data['Ord_Month'] = data['Order Date'].dt.month
data['Ord_Year'] = data['Order Date'].dt.year

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Ord_Day', 'Ord_Month', 'Ord_Year'],
#       dtype='object')

# %%
data.drop('Order Date', axis=1, inplace=True)

# %%
data['Ship Date'] = pd.to_datetime(data['Ship Date'], format='%d/%m/%Y')
data['Ship_Day'] = data['Ship Date'].dt.day
data['Ship_Month'] = data['Ship Date'].dt.month
data['Ship_Year'] = data['Ship Date'].dt.year

# %%
data.columns
# Out:
# Index(['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID',
#        'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name',
#        'Sales', 'Ord_Day', 'Ord_Month', 'Ord_Year', 'Ship_Day', 'Ship_Month',
#        'Ship_Year'],
#       dtype='object')

# %%
data.drop('Ship Date', axis=1, inplace=True)

# %%
data.shape
# Out:
# (9789, 22)

# %%
data.dtypes
# Out:
# Row ID            int64
# Order ID         object
# Ship Mode        object
# Customer ID      object
# Customer Name    object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int32
# Region           object
# Product ID       object
# Category         object
# Sub-Category     object
# Product Name     object
# Sales             int32
# Ord_Day           int32
# Ord_Month         int32
# Ord_Year          int32
# Ship_Day          int32
# Ship_Month        int32
# Ship_Year         int32
# dtype: object

# %%
Cat_data= data.select_dtypes('object')
for i in Cat_data:
    data= data.drop(i, axis=1)

# %%
Cat_data.head(3)
# Out:
#          Order ID     Ship Mode Customer ID    Customer Name    Segment  \
# 0  CA-2017-152156  Second Class    CG-12520      Claire Gute   Consumer
# 1  CA-2017-152156  Second Class    CG-12520      Claire Gute   Consumer
# 2  CA-2017-138688  Second Class    DV-13045  Darrin Van Huff  Corporate
#
#          Country         City       State Region       Product ID  \
# 0  United States    Henderson    Kentucky  South  FUR-BO-10001798
# 1  United States    Henderson    Kentucky  South  FUR-CH-10000454
# 2  United States  Los Angeles  California   West  OFF-LA-10000240
#
#           Category Sub-Category  \
# 0        Furniture    Bookcases
# 1        Furniture       Chairs
# 2  Office Supplies       Labels
#
#                                         Product Name
# 0                  Bush Somerset Collection Bookcase
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...
# 2  Self-Adhesive Address Labels for Typewriters b...

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
for i in Cat_data:
    Cat_data[i] = label_encoder.fit_transform(Cat_data[i])

# %%
Cat_data
# Out:
#       Order ID  Ship Mode  Customer ID  Customer Name  Segment  Country  City  \
# 0         2454          2          143            166        0        0   194
# 1         2454          2          143            166        0        0   194
# 2         2252          2          237            201        1        0   265
# 3         4292          3          705            687        0        0   153
# 4         4292          3          705            687        0        0   153
# ...        ...        ...          ...            ...      ...      ...   ...
# 9795      2062          3          691            663        1        0    80
# 9796      1143          3          179            164        1        0   483
# 9797      1143          3          179            164        1        0   483
# 9798      1143          3          179            164        1        0   483
# 9799      1143          3          179            164        1        0   483
#
# ...

# %%
df = pd.concat([data,Cat_data],axis=1)

# %%
df
# Out:
#       Row ID  Postal Code  Sales  Ord_Day  Ord_Month  Ord_Year  Ship_Day  \
# 0          1        42420    261        8         11      2017        11
# 1          2        42420    731        8         11      2017        11
# 2          3        90036     14       12          6      2017        16
# 3          4        33311    957       11         10      2016        18
# 4          5        33311     22       11         10      2016        18
# ...      ...          ...    ...      ...        ...       ...       ...
# 9795    9796        60610      3       21          5      2017        28
# 9796    9797        43615     10       12          1      2016        17
# 9797    9798        43615    235       12          1      2016        17
# 9798    9799        43615     26       12          1      2016        17
# 9799    9800        43615     10       12          1      2016        17
#
#       Ship_Month  Ship_Year  Order ID  ...  Customer Name  Segment  Country  \
# ...

# %%
sales_column = 'Sales'
columns = df.columns.tolist()
columns.remove(sales_column)
columns.append(sales_column)
df = df[columns]

# %%
df.head(3)
# Out:
#    Row ID  Postal Code  Ord_Day  Ord_Month  Ord_Year  Ship_Day  Ship_Month  \
# 0       1        42420        8         11      2017        11          11
# 1       2        42420        8         11      2017        11          11
# 2       3        90036       12          6      2017        16           6
#
#    Ship_Year  Order ID  Ship Mode  ...  Segment  Country  City  State  Region  \
# 0       2017      2454          2  ...        0        0   194     15       2
# 1       2017      2454          2  ...        0        0   194     15       2
# 2       2017      2252          2  ...        1        0   265      3       3
#
#    Product ID  Category  Sub-Category  Product Name  Sales
# 0          12         0             4           385    261
# 1          55         0             5           837    731
# 2         945         1            10          1431     14
#
# [3 rows x 22 columns]

# %% [markdown]
# # Visualizations

# %%
segment_by_sales = df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)

# %%
segment_by_sales
# Out:
# Segment
# 0    1143695
# 1     680468
# 2     422663
# Name: Sales, dtype: int32

# %%
plt.figure(figsize=(5, 4))  
sns.barplot(x=segment_by_sales.index, y=segment_by_sales.values)
plt.xlabel('Segment')
plt.ylabel('Total Sales')
plt.title('Total Sales by Segment')  
plt.show()

# %%
ship_year_sales = df.groupby('Ship_Year')['Sales'].sum().sort_values(ascending=False)

# %%
ship_year_sales
# Out:
# Ship_Year
# 2018    716966
# 2017    597865
# 2015    465915
# 2016    460945
# 2019      5135
# Name: Sales, dtype: int32

# %%
plt.figure(figsize=(5, 4))  
sns.barplot(x=ship_year_sales.index, y=ship_year_sales.values)
plt.xlabel('Years by Shipping')
plt.ylabel('Total Sales')
plt.title('Total Sales by Shipping year')  
plt.show()

# %%
ship_month_sales = df.groupby('Ship_Month')['Sales'].sum().sort_values(ascending=False)

# %%
ship_month_sales
# Out:
# Ship_Month
# 12    336738
# 11    322419
# 9     297635
# 10    202077
# 3     183806
# 6     154289
# 8     151851
# 7     145984
# 5     145025
# 4     133472
# 1     105181
# 2      68349
# Name: Sales, dtype: int32

# %%
plt.figure(figsize=(5, 4))  
sns.lineplot(x=ship_month_sales.index, y=ship_month_sales.values)
plt.xlabel('Months by Shipping')
plt.ylabel('Total Sales')
plt.title('Total Sales by Shipping Month')  
plt.show()

# %%
Category_by_Sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False)

# %%
Category_by_Sales
# Out:
# Category
# 2    824542
# 0    722356
# 1    699928
# Name: Sales, dtype: int32

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=Category_by_Sales.index, y=Category_by_Sales.values)
plt.xlabel('Total Categories')
plt.ylabel('Total Sales')
plt.title('Total Sales by Categories')
plt.show()

# %%
Segment_by_Category = df.groupby('Segment')['Category'].sum().sort_values(ascending=False)

# %%
Segment_by_Category
# Out:
# Segment
# 0    4940
# 1    2861
# 2    1722
# Name: Category, dtype: int32

# %%
plt.figure(figsize=(5,4))
sns.barplot(x=Segment_by_Category.index, y=Segment_by_Category.values)
plt.xlabel('Segments')
plt.ylabel('Categories')
plt.title('Segments by Product Categories')
plt.show()

# %% [markdown]
# # Ml Model Building

# %%
from sklearn.feature_selection import mutual_info_classif

# %%
X = df.drop(['Sales'], axis=1)
Y = df['Sales']

# %%
imp_df=pd.DataFrame(mutual_info_classif(X,Y), index=X.columns)

# %%
imp_df.to_csv('imp_df')
a=pd.read_csv('imp_df')
a
# Out:
#        Unnamed: 0         0
# 0          Row ID  0.080305
# 1     Postal Code  0.199701
# 2         Ord_Day  0.067670
# 3       Ord_Month  0.076080
# 4        Ord_Year  0.112606
# 5        Ship_Day  0.085064
# 6      Ship_Month  0.105743
# 7       Ship_Year  0.134962
# 8        Order ID  0.094167
# 9       Ship Mode  0.388265
# 10    Customer ID  0.120143
# 11  Customer Name  0.098710
# 12        Segment  0.038115
# 13        Country  0.000000
# 14           City  0.107684
# 15          State  0.117576
# 16         Region  0.127898
# 17     Product ID  0.349659
# 18       Category  0.397903
# 19   Sub-Category  0.314683
# 20   Product Name  0.451190

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, Y_train)
prediction = model.predict(X_test)
mse = mean_squared_error(Y_test, prediction)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 484323.1969180632

# %%
actual_values = Y_test
predicted_values = prediction
print("Actual Values:", actual_values[:5])
print("Predicted Values:", predicted_values[:5])
# Out:
# Actual Values: 8962     273
# 7138      62
# 4709      11
# 6204       7
# 6901    2399
# Name: Sales, dtype: int32
# Predicted Values: [208.57099071 203.44671442 218.28688715 162.10715069 256.20008404]

# %%
# Scatter plot of actual vs predicted values
plt.figure(figsize=(8, 6))
sns.scatterplot(x=actual_values, y=predicted_values)
plt.xlabel('Actual Values')
plt.ylabel('Predicted Values')
plt.title('Actual vs Predicted Values')
plt.show()

# %%
# Residual plot
residuals = actual_values - predicted_values
plt.figure(figsize=(8, 6))
sns.scatterplot(x=predicted_values, y=residuals)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Predicted Values')
plt.ylabel('Residuals')
plt.title('Residual Plot')
plt.show()

# %%
# Distribution plot of residuals
plt.figure(figsize=(8, 6))
sns.histplot(residuals, kde=True)
plt.xlabel('Residuals')
plt.ylabel('Frequency')
plt.title('Distribution of Residuals')
plt.show()
